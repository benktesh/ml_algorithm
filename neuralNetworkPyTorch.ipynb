# %%
pip install pytorch
# Out:
# Collecting pytorch
#   Downloading pytorch-1.0.2.tar.gz (689 bytes)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: pytorch
#   Building wheel for pytorch (setup.py): started
#   Building wheel for pytorch (setup.py): finished with status 'error'
#   Running setup.py clean for pytorch
# Failed to build pytorch
# Note: you may need to restart the kernel to use updated packages.
#   DEPRECATION: Building 'pytorch' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'pytorch'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#           exec(compile('''
#           ~~~~^^^^^^^^^^^^
#           # This is <pip-setuptools-caller> -- a caller that pip uses to run setup.py
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#           ...<32 lines>...
#           exec(compile(setup_py_code, filename, "exec"))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#           ''' % ('C:\\Users\\BenkteshSharma\\AppData\\Local\\Temp\\pip-install-_wgr82hm\\pytorch_64142fdd080f4b1196fc2f9098380cc9\\setup.py',), "<pip-setuptools-caller>", "exec"))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "<pip-setuptools-caller>", line 35, in <module>
#         File "C:\Users\BenkteshSharma\AppData\Local\Temp\pip-install-_wgr82hm\pytorch_64142fdd080f4b1196fc2f9098380cc9\setup.py", line 15, in <module>
#           raise Exception(message)
#       Exception: You tried to install "pytorch". The package named for PyTorch is "torch"
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pytorch
# error: failed-wheel-build-for-install
#
# × Failed to build installable wheels for some pyproject.toml based projects
# ╰─> pytorch

# %%
pip install azureml-core
# Out:
# Requirement already satisfied: azureml-core in c:\repo\scratch\ml\mlvenv\lib\site-packages (1.60.0.post1)
# Requirement already satisfied: pytz in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (2025.2)
# Requirement already satisfied: backports.tempfile in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (1.0)
# Requirement already satisfied: pathspec<1.0.0 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (0.12.1)
# Requirement already satisfied: requests<3.0.0,>=2.19.1 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core) (2.32.5)
# Requirement already satisfied: msal<2.0.0,>=1.15.0 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (1.34.0)
# Requirement already satisfied: msal-extensions<=2.0.0,>=0.3.0 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (1.3.1)
# Requirement already satisfied: knack<0.13.0 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (0.12.0)
# Requirement already satisfied: azure-core<2.0.0 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (1.36.0)
# Requirement already satisfied: pkginfo in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (1.12.1.2)
# Requirement already satisfied: argcomplete<4 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (3.6.2)
# Requirement already satisfied: humanfriendly<11.0,>=4.7 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (10.0)
# Requirement already satisfied: paramiko<4.0.0,>=2.0.8 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (3.5.1)
# Requirement already satisfied: azure-mgmt-resource<=24.0.0,>=15.0.0 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (24.0.0)
# Requirement already satisfied: azure-mgmt-containerregistry<14,>=8.2.0 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (13.0.0)
# Requirement already satisfied: azure-mgmt-storage<=23.0.0,>=16.0.0 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (23.0.0)
# Requirement already satisfied: azure-mgmt-keyvault<12.0.0,>=0.40.0 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (11.0.0)
# Requirement already satisfied: azure-mgmt-authorization<5,>=0.40.0 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (4.0.0)
# Requirement already satisfied: azure-mgmt-network<=29.0.0 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (29.0.0)
# Requirement already satisfied: azure-graphrbac<1.0.0,>=0.40.0 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (0.61.2)
# Requirement already satisfied: azure-common<2.0.0,>=1.1.12 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (1.1.28)
# Requirement already satisfied: msrest<=0.7.1,>=0.5.1 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (0.7.1)
# Requirement already satisfied: msrestazure<=0.7,>=0.4.33 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (0.6.4.post1)
# Requirement already satisfied: urllib3<3.0.0,>1.26.17 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (2.5.0)
# Requirement already satisfied: packaging<26.0,>=20.0 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (25.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (2.9.0.post0)
# Requirement already satisfied: ndg-httpsclient<=0.5.1 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (0.5.1)
# Requirement already satisfied: SecretStorage<4.0.0 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (3.4.0)
# Requirement already satisfied: jsonpickle<5.0.0 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (4.1.1)
# Requirement already satisfied: contextlib2<22.0.0 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (21.6.0)
# Requirement already satisfied: docker<8.0.0 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (7.1.0)
# Requirement already satisfied: PyJWT<3.0.0 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (2.10.1)
# Requirement already satisfied: adal<=1.2.7,>=1.2.0 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (1.2.7)
# Requirement already satisfied: pyopenssl<26.0.0 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (25.3.0)
# Requirement already satisfied: jmespath<2.0.0 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azureml-core) (1.0.1)
# Requirement already satisfied: cryptography>=1.1.0 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from adal<=1.2.7,>=1.2.0->azureml-core) (46.0.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azure-core<2.0.0->azureml-core) (4.15.0)
# Requirement already satisfied: isodate<1.0.0,>=0.6.1 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azure-mgmt-authorization<5,>=0.40.0->azureml-core) (0.7.2)
# Requirement already satisfied: azure-mgmt-core<2.0.0,>=1.3.2 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from azure-mgmt-authorization<5,>=0.40.0->azureml-core) (1.6.0)
# Requirement already satisfied: pywin32>=304 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from docker<8.0.0->azureml-core) (311)
# Requirement already satisfied: pyreadline3 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from humanfriendly<11.0,>=4.7->azureml-core) (3.5.4)
# Requirement already satisfied: pygments in c:\repo\scratch\ml\mlvenv\lib\site-packages (from knack<0.13.0->azureml-core) (2.19.2)
# Requirement already satisfied: pyyaml in c:\repo\scratch\ml\mlvenv\lib\site-packages (from knack<0.13.0->azureml-core) (6.0.3)
# Requirement already satisfied: tabulate in c:\repo\scratch\ml\mlvenv\lib\site-packages (from knack<0.13.0->azureml-core) (0.9.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from cryptography>=1.1.0->adal<=1.2.7,>=1.2.0->azureml-core) (2.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from msrest<=0.7.1,>=0.5.1->azureml-core) (2025.10.5)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from msrest<=0.7.1,>=0.5.1->azureml-core) (2.0.0)
# Requirement already satisfied: six in c:\repo\scratch\ml\mlvenv\lib\site-packages (from msrestazure<=0.7,>=0.4.33->azureml-core) (1.17.0)
# Requirement already satisfied: pyasn1>=0.1.1 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from ndg-httpsclient<=0.5.1->azureml-core) (0.6.1)
# Requirement already satisfied: bcrypt>=3.2 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from paramiko<4.0.0,>=2.0.8->azureml-core) (5.0.0)
# Requirement already satisfied: pynacl>=1.5 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from paramiko<4.0.0,>=2.0.8->azureml-core) (1.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from requests<3.0.0,>=2.19.1->requests[socks]<3.0.0,>=2.19.1->azureml-core) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from requests<3.0.0,>=2.19.1->requests[socks]<3.0.0,>=2.19.1->azureml-core) (3.11)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core) (1.7.1)
# Requirement already satisfied: jeepney>=0.6 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from SecretStorage<4.0.0->azureml-core) (0.9.0)
# Requirement already satisfied: pycparser in c:\repo\scratch\ml\mlvenv\lib\site-packages (from cffi>=2.0.0->cryptography>=1.1.0->adal<=1.2.7,>=1.2.0->azureml-core) (2.23)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\repo\scratch\ml\mlvenv\lib\site-packages (from requests-oauthlib>=0.5.0->msrest<=0.7.1,>=0.5.1->azureml-core) (3.3.1)
# Requirement already satisfied: backports.weakref in c:\repo\scratch\ml\mlvenv\lib\site-packages (from backports.tempfile->azureml-core) (1.0.post1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Define a simple neural network with one hidden layer
class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(784, 128)  # Input layer (784 input features)
        self.fc2 = nn.Linear(128, 10)   # Output layer (10 classes)
        self.relu = nn.ReLU()           # Activation function

    def forward(self, x):
        x = self.relu(self.fc1(x))  # Apply ReLU after the first layer
        x = self.fc2(x)             # Output layer
        return x

# Initialize the neural network
model = SimpleNN()

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()  # For classification tasks
optimizer = optim.SGD(model.parameters(), lr=0.01)  # Stochastic Gradient Descent

# %%
from torchvision import datasets, transforms

# Load MNIST dataset
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST(root='data', train=True, download=True,
                   transform=transforms.ToTensor()),
    batch_size=32, shuffle=True)

# Train the model
num_epochs = 5
for epoch in range(num_epochs):
    running_loss = 0.0
    for inputs, labels in train_loader:
        optimizer.zero_grad()  # Reset gradients

        # Forward pass
        outputs = model(inputs.view(-1, 784))  # Flatten input
        loss = criterion(outputs, labels)      # Compute loss

        # Backward pass and optimization
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    print(f"Epoch {epoch+1}, Loss: {running_loss/len(train_loader)}")
# Out:
# 100.0%
# 100.0%
# 100.0%
# 100.0%
# Epoch 1, Loss: 0.8806037875493368
# Epoch 2, Loss: 0.3754895622054736
# Epoch 3, Loss: 0.3199008352160454
# Epoch 4, Loss: 0.28855502852201464
# Epoch 5, Loss: 0.26417873152891796
