# %%
# %pip install pytest
# %pip install ipytest
# %pip install scikit-learn
# Out:
# Requirement already satisfied: pytest in ./mlvenv/lib/python3.12/site-packages (9.0.1)
# Requirement already satisfied: iniconfig>=1.0.1 in ./mlvenv/lib/python3.12/site-packages (from pytest) (2.3.0)
# Requirement already satisfied: packaging>=22 in ./mlvenv/lib/python3.12/site-packages (from pytest) (25.0)
# Requirement already satisfied: pluggy<2,>=1.5 in ./mlvenv/lib/python3.12/site-packages (from pytest) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in ./mlvenv/lib/python3.12/site-packages (from pytest) (2.19.2)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ipytest in ./mlvenv/lib/python3.12/site-packages (0.14.2)
# Requirement already satisfied: ipython in ./mlvenv/lib/python3.12/site-packages (from ipytest) (9.7.0)
# Requirement already satisfied: packaging in ./mlvenv/lib/python3.12/site-packages (from ipytest) (25.0)
# Requirement already satisfied: pytest>=5.4 in ./mlvenv/lib/python3.12/site-packages (from ipytest) (9.0.1)
# Requirement already satisfied: iniconfig>=1.0.1 in ./mlvenv/lib/python3.12/site-packages (from pytest>=5.4->ipytest) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in ./mlvenv/lib/python3.12/site-packages (from pytest>=5.4->ipytest) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in ./mlvenv/lib/python3.12/site-packages (from pytest>=5.4->ipytest) (2.19.2)
# Requirement already satisfied: decorator>=4.3.2 in ./mlvenv/lib/python3.12/site-packages (from ipython->ipytest) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in ./mlvenv/lib/python3.12/site-packages (from ipython->ipytest) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in ./mlvenv/lib/python3.12/site-packages (from ipython->ipytest) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in ./mlvenv/lib/python3.12/site-packages (from ipython->ipytest) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in ./mlvenv/lib/python3.12/site-packages (from ipython->ipytest) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./mlvenv/lib/python3.12/site-packages (from ipython->ipytest) (3.0.52)
# Requirement already satisfied: stack_data>=0.6.0 in ./mlvenv/lib/python3.12/site-packages (from ipython->ipytest) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in ./mlvenv/lib/python3.12/site-packages (from ipython->ipytest) (5.14.3)
# Requirement already satisfied: wcwidth in ./mlvenv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->ipytest) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./mlvenv/lib/python3.12/site-packages (from jedi>=0.18.1->ipython->ipytest) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in ./mlvenv/lib/python3.12/site-packages (from pexpect>4.3->ipython->ipytest) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in ./mlvenv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython->ipytest) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./mlvenv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython->ipytest) (3.0.0)
# Requirement already satisfied: pure-eval in ./mlvenv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython->ipytest) (0.2.3)
# Requirement already satisfied: ipytest in ./mlvenv/lib/python3.12/site-packages (0.14.2)
# Requirement already satisfied: ipython in ./mlvenv/lib/python3.12/site-packages (from ipytest) (9.7.0)
# Requirement already satisfied: packaging in ./mlvenv/lib/python3.12/site-packages (from ipytest) (25.0)
# Requirement already satisfied: pytest>=5.4 in ./mlvenv/lib/python3.12/site-packages (from ipytest) (9.0.1)
# Requirement already satisfied: iniconfig>=1.0.1 in ./mlvenv/lib/python3.12/site-packages (from pytest>=5.4->ipytest) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in ./mlvenv/lib/python3.12/site-packages (from pytest>=5.4->ipytest) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in ./mlvenv/lib/python3.12/site-packages (from pytest>=5.4->ipytest) (2.19.2)
# Requirement already satisfied: decorator>=4.3.2 in ./mlvenv/lib/python3.12/site-packages (from ipython->ipytest) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in ./mlvenv/lib/python3.12/site-packages (from ipython->ipytest) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in ./mlvenv/lib/python3.12/site-packages (from ipython->ipytest) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in ./mlvenv/lib/python3.12/site-packages (from ipython->ipytest) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in ./mlvenv/lib/python3.12/site-packages (from ipython->ipytest) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./mlvenv/lib/python3.12/site-packages (from ipython->ipytest) (3.0.52)
# Requirement already satisfied: stack_data>=0.6.0 in ./mlvenv/lib/python3.12/site-packages (from ipython->ipytest) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in ./mlvenv/lib/python3.12/site-packages (from ipython->ipytest) (5.14.3)
# Requirement already satisfied: wcwidth in ./mlvenv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->ipytest) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./mlvenv/lib/python3.12/site-packages (from jedi>=0.18.1->ipython->ipytest) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in ./mlvenv/lib/python3.12/site-packages (from pexpect>4.3->ipython->ipytest) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in ./mlvenv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython->ipytest) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./mlvenv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython->ipytest) (3.0.0)
# Requirement already satisfied: pure-eval in ./mlvenv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython->ipytest) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Collecting scikit-learn
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.2-cp312-cp312-macosx_10_13_x86_64.whl.metadata (11 kB)
#   Downloading scikit_learn-1.7.2-cp312-cp312-macosx_10_13_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in ./mlvenv/lib/python3.12/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: numpy>=1.22.0 in ./mlvenv/lib/python3.12/site-packages (from scikit-learn) (1.26.4)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Downloading scipy-1.16.3-cp312-cp312-macosx_14_0_x86_64.whl.metadata (62 kB)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Downloading scipy-1.16.3-cp312-cp312-macosx_14_0_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: joblib>=1.2.0 in ./mlvenv/lib/python3.12/site-packages (from scikit-learn) (1.5.2)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
# Requirement already satisfied: joblib>=1.2.0 in ./mlvenv/lib/python3.12/site-packages (from scikit-learn) (1.5.2)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.7.2-cp312-cp312-macosx_10_13_x86_64.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/9.3 MB ? eta -:--:--Downloading scikit_learn-1.7.2-cp312-cp312-macosx_10_13_x86_64.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 39.8 MB/s  0:00:00 eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 39.8 MB/s  0:00:00 eta 0:00:01
# Downloading scipy-1.16.3-cp312-cp312-macosx_14_0_x86_64.whl (23.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/23.6 MB ? eta -:--:--Downloading scipy-1.16.3-cp312-cp312-macosx_14_0_x86_64.whl (23.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.6/23.6 MB 41.2 MB/s  0:00:00 eta 0:00:01
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.6/23.6 MB 41.2 MB/s  0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, scikit-learn
# Installing collected packages: threadpoolctl, scipy, scikit-learn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [scikit-learn] [scikit-learn]
# Successfully installed scikit-learn-1.7.2 scipy-1.16.3 threadpoolctl-3.6.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [scikit-learn]
# Successfully installed scikit-learn-1.7.2 scipy-1.16.3 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
import ipytest
import pytest
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
import numpy as np

# Load the dataset
iris = load_iris()
X, y = iris.data, iris.target

# Set up the model
model = DecisionTreeClassifier()
model.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
def test_typical_case():
    input_data = np.array([[4.5, 2.3, 1.3, 0.3]])  # Example input for a flower classification model
    expected_output = 0  # Expected output for typical case (Setosa class index)
    result = model.predict(input_data)[0]
    assert result == expected_output, f"Expected {expected_output}, but got {result}"

def test_edge_case_extreme_values():
    input_data = np.array([[10000, 10000, 10000, 10000]])  # Extreme values for flower classification
    try:
        model.predict(input_data)
    except ValueError:
        assert True  # The model should raise a ValueError for extreme inputs
    else:
        assert False, "Expected ValueError for extreme values, but no error was raised"

def test_error_handling_missing_values():
    input_data = np.array([[None, None, None, None]])  # Missing values in input
    try:
        model.predict(input_data)
    except ValueError:
        assert True  # The model should raise a ValueError for missing inputs
    else:
        assert False, "Expected ValueError for missing values, but no error was raised"

# %%
# Run tests using ipytest
ipytest.run('-v')
# Out:
# ======================================= test session starts ========================================
# platform darwin -- Python 3.12.12, pytest-9.0.1, pluggy-1.6.0 -- /Users/utia/repo/ml_algorithm/mlvenv/bin/python
# cachedir: .pytest_cache
# rootdir: /Users/utia/repo/ml_algorithm
# plugins: anyio-4.11.0
# collecting ... collected 3 items
#
# t_cceee5cff62a4fde9b2820259d6f354e.py::test_typical_case PASSED                              [ 33%]
# t_cceee5cff62a4fde9b2820259d6f354e.py::test_edge_case_extreme_values collected 3 items
#
# t_cceee5cff62a4fde9b2820259d6f354e.py::test_typical_case PASSED                              [ 33%]
# t_cceee5cff62a4fde9b2820259d6f354e.py::test_edge_case_extreme_values FAILED                  [ 66%]
# t_cceee5cff62a4fde9b2820259d6f354e.py::test_error_handling_missing_values FAILED             [100%]FAILED                  [ 66%]
# t_cceee5cff62a4fde9b2820259d6f354e.py::test_error_handling_missing_values FAILED             [100%]
#
# ============================================= FAILURES =============================================
# __________________________________ test_edge_case_extreme_values ___________________________________
#
#     def test_edge_case_extreme_values():
#         input_data = np.array([[10000, 10000, 10000, 10000]])  # Extreme values for flower classification
#         try:
#             model.predict(input_data)
#         except ValueError:
#             assert True  # The model should raise a ValueError for extreme inputs
#         else:
# >           assert False, "Expected ValueError for extreme values, but no error was raised"
#                    ^^^^^
# E           AssertionError: Expected ValueError for extreme values, but no error was raised
#
# /var/folders/lq/5n9x10_s3379vpdjpp2drp5m0000gp/T/ipykernel_29163/1300121212.py:14: AssertionError
# ________________________________ test_error_handling_missing_values ________________________________
#
#     def test_error_handling_missing_values():
#         input_data = np.array([[None, None, None, None]])  # Missing values in input
#         try:
#             model.predict(input_data)
#         except ValueError:
#             assert True  # The model should raise a ValueError for missing inputs
#         else:
# >           assert False, "Expected ValueError for missing values, but no error was raised"
#                    ^^^^^
# E           AssertionError: Expected ValueError for missing values, but no error was raised
#
# /var/folders/lq/5n9x10_s3379vpdjpp2drp5m0000gp/T/ipykernel_29163/1300121212.py:23: AssertionError
# ===================================== short test summary info ======================================
# FAILED t_cceee5cff62a4fde9b2820259d6f354e.py::test_edge_case_extreme_values - AssertionError: Expected ValueError for extreme values, but no error was raised
# FAILED t_cceee5cff62a4fde9b2820259d6f354e.py::test_error_handling_missing_values - AssertionError: Expected ValueError for missing values, but no error was raised
# =================================== 2 failed, 1 passed in 0.05s ====================================
#
#
# ============================================= FAILURES =============================================
# __________________________________ test_edge_case_extreme_values ___________________________________
#
#     def test_edge_case_extreme_values():
#         input_data = np.array([[10000, 10000, 10000, 10000]])  # Extreme values for flower classification
#         try:
#             model.predict(input_data)
#         except ValueError:
#             assert True  # The model should raise a ValueError for extreme inputs
#         else:
# >           assert False, "Expected ValueError for extreme values, but no error was raised"
#                    ^^^^^
# E           AssertionError: Expected ValueError for extreme values, but no error was raised
#
# /var/folders/lq/5n9x10_s3379vpdjpp2drp5m0000gp/T/ipykernel_29163/1300121212.py:14: AssertionError
# ________________________________ test_error_handling_missing_values ________________________________
#
#     def test_error_handling_missing_values():
#         input_data = np.array([[None, None, None, None]])  # Missing values in input
#         try:
#             model.predict(input_data)
#         except ValueError:
#             assert True  # The model should raise a ValueError for missing inputs
#         else:
# >           assert False, "Expected ValueError for missing values, but no error was raised"
#                    ^^^^^
# E           AssertionError: Expected ValueError for missing values, but no error was raised
#
# /var/folders/lq/5n9x10_s3379vpdjpp2drp5m0000gp/T/ipykernel_29163/1300121212.py:23: AssertionError
# ===================================== short test summary info ======================================
# FAILED t_cceee5cff62a4fde9b2820259d6f354e.py::test_edge_case_extreme_values - AssertionError: Expected ValueError for extreme values, but no error was raised
# FAILED t_cceee5cff62a4fde9b2820259d6f354e.py::test_error_handling_missing_values - AssertionError: Expected ValueError for missing values, but no error was raised
# =================================== 2 failed, 1 passed in 0.05s ====================================
# <ExitCode.TESTS_FAILED: 1>
